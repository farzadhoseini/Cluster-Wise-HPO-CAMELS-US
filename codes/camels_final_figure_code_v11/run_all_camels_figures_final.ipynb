# %%
# %run run_all_camels_figures_final.py --project-root "F:/Experiments/CAMELS_US/Clean_4_upload" --metrics NSE --models "Benchmark,Cluster-wise,Top10" --dpi 300 --clean-outdir
# Out:
# [STYLE] Javi Del Ser palette retained: #56ae6c, #8960b3, #b0923b, #ba495b
# [OUT] Final PDF folder: F:\Experiments\CAMELS_US\Clean_4_upload\results\All_plots
# [TMP] Intermediate helper folder inside All_plots: F:\Experiments\CAMELS_US\Clean_4_upload\results\All_plots\others
# [1/9] Basin attribute and cluster-summary figures: fig01, fig02, fig03, fig13, fig14, fig15
# Confirmed: all outputs are based on the 531 study basins only.
# Done. Outputs written to:
# F:\Experiments\CAMELS_US\Clean_4_upload\results\All_plots\others\CAMELS_US_hydrology
# [2/9] Professional cluster map with national/state/province boundaries for fig01
# [INFO] Loaded 531 basins from: F:\Experiments\CAMELS_US\Clean_4_upload\results\All_plots\others\CAMELS_US_hydrology\camels_531_master_attributes_clusters.csv
# [INFO] Cluster counts:
# cluster
# 1     83
# 2    195
# 3     67
# 4     61
# 5     66
# 6     59
# HTTP Error 401: UnauthorizedHTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# ...

# %%
# %run make_small_web_images.py --all-plots "F:/Experiments/CAMELS_US/Clean_4_upload/results/All_plots"
# Out:
# Input folder : F:\Experiments\CAMELS_US\Clean_4_upload\results\All_plots
# Output folder: F:\Experiments\CAMELS_US\Clean_4_upload\results\All_plots\small
# Images found : 30
# --------------------------------------------------------------------------------
# fig01_map_clusters.png                           -> fig01_map_clusters.webp                             1.6 MB ->   99.7 KB (  6.1%)
# fig02_hydrological_signature_distributions.png   -> fig02_hydrological_signature_distributions.webp   643.6 KB ->   57.7 KB (  9.0%)
# fig03_cluster_profile_heatmap.png                -> fig03_cluster_profile_heatmap.webp                580.4 KB ->   63.5 KB ( 10.9%)
# fig04_BOX_basins__NSE.png                        -> fig04_BOX_basins__NSE.webp                        155.3 KB ->   31.7 KB ( 20.4%)
# fig05_ECDF_split_basins__NSE.png                 -> fig05_ECDF_split_basins__NSE.webp                 314.3 KB ->   35.7 KB ( 11.4%)
# ...
