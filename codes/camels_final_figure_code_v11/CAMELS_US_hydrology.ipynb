# %%
# %run camels_us_hydrology_summary_plots.py
# Out:
# Confirmed: all outputs are based on the 531 study basins only.
# Done. Outputs written to:
# F:\Experiments\CAMELS_US\Clean_4_upload\CAMELS_US_hydrology

# %%
# %run plot_camels_clusters_pro_map.py --input "F:/Experiments/CAMELS_US/Clean_4_upload/camels_531_master_attributes_clusters.csv" --output "F:/Experiments/CAMELS_US/Clean_4_upload/results/fig_camels_clusters_map_pro.png"
# Out:
# [INFO] Loaded 531 basins from: F:\Experiments\CAMELS_US\Clean_4_upload\camels_531_master_attributes_clusters.csv
# [INFO] Cluster counts:
# cluster
# 1     83
# 2    195
# 3     67
# 4     61
# 5     66
# 6     59
# HTTP Error 401: UnauthorizedHTTP Error 401: Unauthorized
#
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# HTTP Error 401: Unauthorized
# ...
